# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
## -- Provided Code -- ##
# Dependencies and Setup
import matplotlib.pyplot as plt
import openweathermapy as owm
from pprint import pprint
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
weather_data_csv = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
## -- Provided Code -- ##
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %%
## -- Personal Code -- ##
# Basic URL to interact with OpenWeatherMap's API
base_url = "http://api.openweathermap.org/data/2.5/weather?&appid=" + api_key

# Basic settings for the data pull - Similar to work done in Ins_OpenWeatherWrapper
settings = {"units": "imperial", "appid": api_key}

# Summary list of required data. Looked at a single API pull for the setup of the returned json data:
#(http://api.openweathermap.org/data/2.5/weather?appid={apikey}&q=city&units=imperial). 
# Similar to work done in Ins_OpenWeatherWrapper but using **kwargs insteead of *args
data_list = ['name' ,'clouds.all','sys.country','dt','main.humidity','main.temp_max','wind.speed','coord.lat','coord.lon']

# testing current setup
# test_data = owm.get_current("la jolla", **settings) 
# summary_test = test_data(*summary)
# pprint(summary_test)
# ('La Jolla', 1, 'US', 1567465761, 65, -117.27, 32.85, 93.2, 4.7)

# Empty lists to store the pulled data
lng = []
lat = []
date = []
temp = []
country = []
city_list = []
humidity  = []
wind_speed = []
cloudiness = []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Setting initial states for the counters. It appears from the original code ipynb that the returned data needs to be broken up into Sets after getting 50 or so results. 
city_count = 1
set_count = 1
total_pulled = 1

# Creating a small list of cities to use for testing
# temp_city_list = ['riverside', 'la jolla', 'dahlonega', 'paris']

print(f"-----------------------------\nBeginning Data Retrieval\n-----------------------------")
for city in cities:
    city_pull_url = base_url + '&q=' + city.replace(' ','+')
    print(f"Processing request #{city_count} of Set #{set_count} | {city.title()}")
    try:
        city_weather_data = owm.get_current(city, **settings)
        name, clds, cntry, dte, humid, long, lati, tmp, wind = city_weather_data(*data_list)
        city_list.append(name)
        cloudiness.append(clds)
        country.append(cntry)
        date.append(dte)
        humidity.append(humid)
        lng.append(long)
        lat.append(lati)
        temp.append(tmp)
        wind_speed.append(wind)
        if city_count > 49:
            city_count = 1
            set_count += 1
    except Exception:
        print(f"City {city} not found. Skipping... {city_pull_url}")
    city_count += 1
    total_pulled += 1
print(f"-----------------------------\n{total_pulled} Records Pulled\n-----------------------------\n-----------------------------\nRetrival Finished, Yo!\n-----------------------------")
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing request #1 of Set #1 | Cape Town
# Processing request #2 of Set #1 | Castro
# Processing request #3 of Set #1 | Samusu
# City samusu not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=samusu
# Processing request #4 of Set #1 | Tigre
# Processing request #5 of Set #1 | Marcona
# City marcona not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=marcona
# Processing request #6 of Set #1 | Caledon
# Processing request #7 of Set #1 | Leningradskiy
# Processing request #8 of Set #1 | Khatanga
# Processing request #9 of Set #1 | Turukhansk
# Processing request #10 of Set #1 | Puerto Ayora
# Processing request #11 of Set #1 | Ancud
# Processing request #12 of Set #1 | Ayan
# Processing request #13 of Set #1 | Rikitea
# Processing request #14 of Set #1 | Dhidhdhoo
# Processing request #15 of Set #1 | Aklavik
# Processing request #16 of Set #1 | Mar Del Plata
# Processing request #17 of Set #1 | Bredasdorp
# Processing request #18 of Set #1 | Bluff
# Processing request #19 of Set #1 | Alora
# Processing request #20 of Set #1 | Arraial Do Cabo
# Processing request #21 of Set #1 | Busselton
# Processing request #22 of Set #1 | Saskylakh
# Processing request #23 of Set #1 | Hobart
# Processing request #24 of Set #1 | Pundaguitan
# Processing request #25 of Set #1 | Mys Shmidta
# City mys shmidta not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=mys+shmidta
# Processing request #26 of Set #1 | Taltal
# Processing request #27 of Set #1 | Qaanaaq
# Processing request #28 of Set #1 | Ler
# Processing request #29 of Set #1 | Mataura
# Processing request #30 of Set #1 | Syzran
# Processing request #31 of Set #1 | Vaini
# Processing request #32 of Set #1 | Kurilsk
# Processing request #33 of Set #1 | Amderma
# City amderma not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=amderma
# Processing request #34 of Set #1 | Port Alfred
# Processing request #35 of Set #1 | Pevek
# Processing request #36 of Set #1 | Albany
# Processing request #37 of Set #1 | Urumqi
# City urumqi not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=urumqi
# Processing request #38 of Set #1 | Hermanus
# Processing request #39 of Set #1 | Taolanaro
# City taolanaro not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=taolanaro
# Processing request #40 of Set #1 | Tarija
# Processing request #41 of Set #1 | Nanortalik
# Processing request #42 of Set #1 | Port Elizabeth
# Processing request #43 of Set #1 | Satipo
# Processing request #44 of Set #1 | Cherskiy
# Processing request #45 of Set #1 | Illoqqortoormiut
# City illoqqortoormiut not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=illoqqortoormiut
# Processing request #46 of Set #1 | Hilo
# Processing request #47 of Set #1 | Coihaique
# Processing request #48 of Set #1 | Grand River South East
# City grand river south east not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=grand+river+south+east
# Processing request #49 of Set #1 | Ferkessedougou
# Processing request #50 of Set #1 | Norman Wells
# Processing request #2 of Set #2 | Jamestown
# Processing request #3 of Set #2 | Qandala
# Processing request #4 of Set #2 | Ushuaia
# Processing request #5 of Set #2 | Barentsburg
# City barentsburg not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=barentsburg
# Processing request #6 of Set #2 | Tecolutla
# Processing request #7 of Set #2 | Daru
# Processing request #8 of Set #2 | Kita
# Processing request #9 of Set #2 | Ardesen
# Processing request #10 of Set #2 | Cabras
# Processing request #11 of Set #2 | Cabedelo
# Processing request #12 of Set #2 | Clyde River
# Processing request #13 of Set #2 | Nikolskoye
# Processing request #14 of Set #2 | Salalah
# Processing request #15 of Set #2 | Glenwood Springs
# Processing request #16 of Set #2 | Tuatapere
# Processing request #17 of Set #2 | Qaqortoq
# Processing request #18 of Set #2 | Punta Arenas
# Processing request #19 of Set #2 | Sao Filipe
# Processing request #20 of Set #2 | General Pico
# Processing request #21 of Set #2 | Tuktoyaktuk
# Processing request #22 of Set #2 | Thompson
# Processing request #23 of Set #2 | Nizhneyansk
# City nizhneyansk not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=nizhneyansk
# Processing request #24 of Set #2 | Nizhnetroitskiy
# Processing request #25 of Set #2 | Villa Bruzual
# Processing request #26 of Set #2 | Garissa
# Processing request #27 of Set #2 | Masyaf
# Processing request #28 of Set #2 | Yerbogachen
# Processing request #29 of Set #2 | Kamenka
# Processing request #30 of Set #2 | Mujiayingzi
# Processing request #31 of Set #2 | Sayan
# Processing request #32 of Set #2 | Ribeira Grande
# Processing request #33 of Set #2 | Raichur
# Processing request #34 of Set #2 | Asau
# City asau not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=asau
# Processing request #35 of Set #2 | Brae
# Processing request #36 of Set #2 | Lagoa
# Processing request #37 of Set #2 | Menongue
# Processing request #38 of Set #2 | Tasiilaq
# Processing request #39 of Set #2 | Yellowknife
# Processing request #40 of Set #2 | Victoria
# Processing request #41 of Set #2 | Shingu
# Processing request #42 of Set #2 | Mount Gambier
# Processing request #43 of Set #2 | Husavik
# Processing request #44 of Set #2 | Chokurdakh
# Processing request #45 of Set #2 | Mehamn
# Processing request #46 of Set #2 | Rungata
# City rungata not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=rungata
# Processing request #47 of Set #2 | Klaksvik
# Processing request #48 of Set #2 | Barrow
# Processing request #49 of Set #2 | Nouadhibou
# Processing request #50 of Set #2 | Kapaa
# Processing request #2 of Set #3 | Pisco
# Processing request #3 of Set #3 | Kodiak
# Processing request #4 of Set #3 | Sao Bento
# City sao bento not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=sao+bento
# Processing request #5 of Set #3 | Lolua
# City lolua not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=lolua
# Processing request #6 of Set #3 | Wuda
# Processing request #7 of Set #3 | Souillac
# Processing request #8 of Set #3 | Huarmey
# Processing request #9 of Set #3 | Pimenteiras
# Processing request #10 of Set #3 | Port Lincoln
# Processing request #11 of Set #3 | Belushya Guba
# City belushya guba not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=belushya+guba
# Processing request #12 of Set #3 | Novoagansk
# Processing request #13 of Set #3 | Shubarshi
# Processing request #14 of Set #3 | Takoradi
# Processing request #15 of Set #3 | Sao Raimundo Nonato
# City sao raimundo nonato not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=sao+raimundo+nonato
# Processing request #16 of Set #3 | Saleaula
# City saleaula not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=saleaula
# Processing request #17 of Set #3 | Anloga
# Processing request #18 of Set #3 | Bur Gabo
# City bur gabo not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=bur+gabo
# Processing request #19 of Set #3 | Teknaf
# Processing request #20 of Set #3 | Karamken
# City karamken not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=karamken
# Processing request #21 of Set #3 | Atuona
# Processing request #22 of Set #3 | Lebu
# Processing request #23 of Set #3 | Carutapera
# Processing request #24 of Set #3 | Yumen
# Processing request #25 of Set #3 | Ngunguru
# Processing request #26 of Set #3 | Port Blair
# Processing request #27 of Set #3 | Carnarvon
# Processing request #28 of Set #3 | Kavieng
# Processing request #29 of Set #3 | Tautira
# Processing request #30 of Set #3 | East London
# Processing request #31 of Set #3 | Mahenge
# Processing request #32 of Set #3 | Naze
# Processing request #33 of Set #3 | Mahebourg
# Processing request #34 of Set #3 | Airai
# Processing request #35 of Set #3 | Xapuri
# Processing request #36 of Set #3 | Warqla
# City warqla not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=warqla
# Processing request #37 of Set #3 | Villa Union
# Processing request #38 of Set #3 | Acapulco
# Processing request #39 of Set #3 | Hun
# Processing request #40 of Set #3 | Nam Phong
# Processing request #41 of Set #3 | Peniche
# Processing request #42 of Set #3 | Isangel
# Processing request #43 of Set #3 | Vila Velha
# Processing request #44 of Set #3 | Petit Goave
# Processing request #45 of Set #3 | Synya
# Processing request #46 of Set #3 | Flinders
# Processing request #47 of Set #3 | Haines Junction
# Processing request #48 of Set #3 | Stokmarknes
# Processing request #49 of Set #3 | Nerchinskiy Zavod
# Processing request #50 of Set #3 | Gangarampur
# Processing request #2 of Set #4 | Portland
# Processing request #3 of Set #4 | Abu Kamal
# Processing request #4 of Set #4 | Dwarka
# Processing request #5 of Set #4 | Marquette
# Processing request #6 of Set #4 | Vardo
# Processing request #7 of Set #4 | Doka
# Processing request #8 of Set #4 | Bartica
# Processing request #9 of Set #4 | Evensk
# Processing request #10 of Set #4 | Araouane
# Processing request #11 of Set #4 | Hithadhoo
# Processing request #12 of Set #4 | Kloulklubed
# Processing request #13 of Set #4 | Upernavik
# Processing request #14 of Set #4 | Saint-Philippe
# Processing request #15 of Set #4 | Allada
# Processing request #16 of Set #4 | Ghanzi
# Processing request #17 of Set #4 | Longonjo
# Processing request #18 of Set #4 | Dikson
# Processing request #19 of Set #4 | Torbay
# Processing request #20 of Set #4 | New Norfolk
# Processing request #21 of Set #4 | Lorengau
# Processing request #22 of Set #4 | Ryotsu
# Processing request #23 of Set #4 | Mangrol
# Processing request #24 of Set #4 | Muncar
# Processing request #25 of Set #4 | Gudari
# Processing request #26 of Set #4 | Balikpapan
# Processing request #27 of Set #4 | Longyearbyen
# Processing request #28 of Set #4 | Umzimvubu
# City umzimvubu not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=umzimvubu
# Processing request #29 of Set #4 | Krasnoselkup
# City krasnoselkup not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=krasnoselkup
# Processing request #30 of Set #4 | Karaul
# City karaul not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=karaul
# Processing request #31 of Set #4 | Aykhal
# Processing request #32 of Set #4 | Aswan
# Processing request #33 of Set #4 | Zakamensk
# Processing request #34 of Set #4 | Saldanha
# Processing request #35 of Set #4 | Gouyave
# Processing request #36 of Set #4 | Katsuura
# Processing request #37 of Set #4 | Manokwari
# Processing request #38 of Set #4 | Georgetown
# Processing request #39 of Set #4 | Mendoza
# Processing request #40 of Set #4 | Dunedin
# Processing request #41 of Set #4 | Provideniya
# Processing request #42 of Set #4 | Miraflores
# Processing request #43 of Set #4 | Luanda
# Processing request #44 of Set #4 | Macheng
# Processing request #45 of Set #4 | Pontianak
# Processing request #46 of Set #4 | Ayolas
# Processing request #47 of Set #4 | Lexington
# Processing request #48 of Set #4 | Sentyabrskiy
# City sentyabrskiy not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=sentyabrskiy
# Processing request #49 of Set #4 | Almaznyy
# Processing request #50 of Set #4 | Marystown
# Processing request #2 of Set #5 | Vaitupu
# City vaitupu not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=vaitupu
# Processing request #3 of Set #5 | Altamira
# Processing request #4 of Set #5 | Ziro
# Processing request #5 of Set #5 | Egvekinot
# Processing request #6 of Set #5 | Dingle
# Processing request #7 of Set #5 | Kaitangata
# Processing request #8 of Set #5 | Juneau
# Processing request #9 of Set #5 | Luderitz
# Processing request #10 of Set #5 | Rawson
# Processing request #11 of Set #5 | Rudbar
# City rudbar not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=rudbar
# Processing request #12 of Set #5 | Butaritari
# Processing request #13 of Set #5 | Sungaipenuh
# Processing request #14 of Set #5 | Susehri
# Processing request #15 of Set #5 | Hamilton
# Processing request #16 of Set #5 | Liverpool
# Processing request #17 of Set #5 | Iguape
# Processing request #18 of Set #5 | Buenos Aires
# Processing request #19 of Set #5 | Morro Bay
# Processing request #20 of Set #5 | Hasaki
# Processing request #21 of Set #5 | Gao
# Processing request #22 of Set #5 | Maine-Soroa
# Processing request #23 of Set #5 | Shihezi
# Processing request #24 of Set #5 | Marsaxlokk
# Processing request #25 of Set #5 | North Bend
# Processing request #26 of Set #5 | Qasigiannguit
# Processing request #27 of Set #5 | Narsaq
# Processing request #28 of Set #5 | Kemijarvi
# City kemijarvi not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=kemijarvi
# Processing request #29 of Set #5 | Bandarbeyla
# Processing request #30 of Set #5 | Fort Nelson
# Processing request #31 of Set #5 | Aksu
# Processing request #32 of Set #5 | Shahrud
# Processing request #33 of Set #5 | Cozumel
# City cozumel not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=cozumel
# Processing request #34 of Set #5 | Berlevag
# Processing request #35 of Set #5 | Sukhoverkovo
# City sukhoverkovo not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=sukhoverkovo
# Processing request #36 of Set #5 | Muvattupula
# Processing request #37 of Set #5 | Marovoay
# Processing request #38 of Set #5 | Meulaboh
# Processing request #39 of Set #5 | Luganville
# Processing request #40 of Set #5 | Deep River
# Processing request #41 of Set #5 | Amurzet
# Processing request #42 of Set #5 | Bengkulu
# City bengkulu not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=bengkulu
# Processing request #43 of Set #5 | Tiksi
# Processing request #44 of Set #5 | Nome
# Processing request #45 of Set #5 | Adrar
# Processing request #46 of Set #5 | Camacha
# Processing request #47 of Set #5 | Touros
# Processing request #48 of Set #5 | Flin Flon
# Processing request #49 of Set #5 | Capim Grosso
# Processing request #50 of Set #5 | Inhambane
# Processing request #2 of Set #6 | Chingola
# Processing request #3 of Set #6 | Kruisfontein
# Processing request #4 of Set #6 | Koutiala
# Processing request #5 of Set #6 | Moron
# Processing request #6 of Set #6 | Coquimbo
# Processing request #7 of Set #6 | Huanuco
# Processing request #8 of Set #6 | Miandrivazo
# Processing request #9 of Set #6 | Vaitape
# Processing request #10 of Set #6 | Angoche
# Processing request #11 of Set #6 | Bolshegrivskoye
# City bolshegrivskoye not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=bolshegrivskoye
# Processing request #12 of Set #6 | Luwuk
# Processing request #13 of Set #6 | Northam
# Processing request #14 of Set #6 | Darnah
# Processing request #15 of Set #6 | Mehriz
# Processing request #16 of Set #6 | Gat
# Processing request #17 of Set #6 | Okhotsk
# Processing request #18 of Set #6 | Guiratinga
# Processing request #19 of Set #6 | Saint-Joseph
# Processing request #20 of Set #6 | Tawkar
# City tawkar not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=tawkar
# Processing request #21 of Set #6 | Labuhan
# Processing request #22 of Set #6 | Winfield
# Processing request #23 of Set #6 | Galle
# Processing request #24 of Set #6 | Kayerkan
# Processing request #25 of Set #6 | Gulabpura
# Processing request #26 of Set #6 | Nampula
# Processing request #27 of Set #6 | Kivsharivka
# Processing request #28 of Set #6 | Antofagasta
# Processing request #29 of Set #6 | Aitape
# Processing request #30 of Set #6 | Laguna
# Processing request #31 of Set #6 | Vicuna
# City vicuna not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=vicuna
# Processing request #32 of Set #6 | Kajaani
# Processing request #33 of Set #6 | Bolshoy Tsaryn
# City bolshoy tsaryn not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=bolshoy+tsaryn
# Processing request #34 of Set #6 | Karratha
# Processing request #35 of Set #6 | Ponta Do Sol
# Processing request #36 of Set #6 | Saint George
# Processing request #37 of Set #6 | Rudnogorsk
# Processing request #38 of Set #6 | Srednekolymsk
# Processing request #39 of Set #6 | Bridlington
# Processing request #40 of Set #6 | Danilov
# Processing request #41 of Set #6 | Hervey Bay
# Processing request #42 of Set #6 | Jingdezhen
# Processing request #43 of Set #6 | Mutoko
# Processing request #44 of Set #6 | Radcliff
# Processing request #45 of Set #6 | Taoudenni
# Processing request #46 of Set #6 | Sitka
# Processing request #47 of Set #6 | Hofn
# Processing request #48 of Set #6 | Tsihombe
# City tsihombe not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=tsihombe
# Processing request #49 of Set #6 | Vanimo
# Processing request #50 of Set #6 | Barawe
# City barawe not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=barawe
# Processing request #51 of Set #6 | Sofiysk
# City sofiysk not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=sofiysk
# Processing request #52 of Set #6 | Mosquera
# Processing request #2 of Set #7 | Lompoc
# Processing request #3 of Set #7 | Tonj
# City tonj not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=tonj
# Processing request #4 of Set #7 | Bathsheba
# Processing request #5 of Set #7 | Faanui
# Processing request #6 of Set #7 | Thunder Bay
# Processing request #7 of Set #7 | Krasnoarmeysk
# Processing request #8 of Set #7 | Xining
# Processing request #9 of Set #7 | Gazli
# Processing request #10 of Set #7 | Da Nang
# City da nang not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=da+nang
# Processing request #11 of Set #7 | Mnogovershinnyy
# Processing request #12 of Set #7 | Port Hardy
# Processing request #13 of Set #7 | Ilirska Bistrica
# Processing request #14 of Set #7 | Chongwe
# Processing request #15 of Set #7 | Grand Centre
# City grand centre not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=grand+centre
# Processing request #16 of Set #7 | Muros
# Processing request #17 of Set #7 | Avarua
# Processing request #18 of Set #7 | Bako
# Processing request #19 of Set #7 | Benjamin Constant
# Processing request #20 of Set #7 | Attawapiskat
# City attawapiskat not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=attawapiskat
# Processing request #21 of Set #7 | Faya
# Processing request #22 of Set #7 | Bambous Virieux
# Processing request #23 of Set #7 | Nisia Floresta
# Processing request #24 of Set #7 | Abilene
# Processing request #25 of Set #7 | Raudeberg
# Processing request #26 of Set #7 | Nuuk
# Processing request #27 of Set #7 | Kieta
# Processing request #28 of Set #7 | Gushikawa
# Processing request #29 of Set #7 | Tabas
# Processing request #30 of Set #7 | Panguna
# Processing request #31 of Set #7 | Nadym
# Processing request #32 of Set #7 | Ngaoundere
# Processing request #33 of Set #7 | Cap Malheureux
# Processing request #34 of Set #7 | Slidell
# Processing request #35 of Set #7 | Xuddur
# Processing request #36 of Set #7 | La Palma
# Processing request #37 of Set #7 | Aldan
# Processing request #38 of Set #7 | Billings
# Processing request #39 of Set #7 | Sistranda
# Processing request #40 of Set #7 | Yueyang
# Processing request #41 of Set #7 | Kapoeta
# City kapoeta not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=kapoeta
# Processing request #42 of Set #7 | Elko
# Processing request #43 of Set #7 | Dauphin
# Processing request #44 of Set #7 | Malibu
# Processing request #45 of Set #7 | Aljezur
# Processing request #46 of Set #7 | Kontagora
# Processing request #47 of Set #7 | Pacifica
# Processing request #48 of Set #7 | Chebsara
# Processing request #49 of Set #7 | Chapleau
# Processing request #50 of Set #7 | Andenes
# City andenes not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=andenes
# Processing request #51 of Set #7 | Carman
# Processing request #2 of Set #8 | Halalo
# City halalo not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=halalo
# Processing request #3 of Set #8 | Manati
# Processing request #4 of Set #8 | Constitucion
# Processing request #5 of Set #8 | Majene
# Processing request #6 of Set #8 | The Colony
# Processing request #7 of Set #8 | Louisbourg
# City louisbourg not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=louisbourg
# Processing request #8 of Set #8 | Yulara
# Processing request #9 of Set #8 | Nemuro
# Processing request #10 of Set #8 | Srandakan
# Processing request #11 of Set #8 | Sola
# Processing request #12 of Set #8 | San Patricio
# Processing request #13 of Set #8 | Arecibo
# Processing request #14 of Set #8 | Porto Novo
# Processing request #15 of Set #8 | Linxia
# Processing request #16 of Set #8 | Bethel
# Processing request #17 of Set #8 | Jumla
# Processing request #18 of Set #8 | Palmer
# Processing request #19 of Set #8 | Olafsvik
# City olafsvik not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=olafsvik
# Processing request #20 of Set #8 | Kassala
# Processing request #21 of Set #8 | Pouembout
# Processing request #22 of Set #8 | Ust-Nera
# Processing request #23 of Set #8 | Lac Du Bonnet
# Processing request #24 of Set #8 | Samarai
# Processing request #25 of Set #8 | Quzhou
# Processing request #26 of Set #8 | Kamwenge
# Processing request #27 of Set #8 | Limbang
# Processing request #28 of Set #8 | Avera
# Processing request #29 of Set #8 | Uyuni
# Processing request #30 of Set #8 | Eureka
# Processing request #31 of Set #8 | Nidzica
# Processing request #32 of Set #8 | Champerico
# Processing request #33 of Set #8 | Lokosovo
# Processing request #34 of Set #8 | Vasto
# Processing request #35 of Set #8 | Tahe
# Processing request #36 of Set #8 | Natal
# Processing request #37 of Set #8 | Chernyshevskiy
# Processing request #38 of Set #8 | Cooma
# Processing request #39 of Set #8 | Ugoofaaru
# Processing request #40 of Set #8 | Biak
# Processing request #41 of Set #8 | Imbituba
# Processing request #42 of Set #8 | Namibe
# Processing request #43 of Set #8 | Gravdal
# Processing request #44 of Set #8 | Bengkalis
# City bengkalis not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=bengkalis
# Processing request #45 of Set #8 | Hornepayne
# Processing request #46 of Set #8 | Chuy
# Processing request #47 of Set #8 | Walvis Bay
# Processing request #48 of Set #8 | Tilichiki
# Processing request #49 of Set #8 | La Ronge
# Processing request #50 of Set #8 | Marsa Matruh
# Processing request #2 of Set #9 | Sisimiut
# Processing request #3 of Set #9 | Margate
# Processing request #4 of Set #9 | Pindiga
# Processing request #5 of Set #9 | Kuche
# City kuche not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=kuche
# Processing request #6 of Set #9 | Allende
# Processing request #7 of Set #9 | Seoul
# Processing request #8 of Set #9 | Noumea
# Processing request #9 of Set #9 | Palu
# Processing request #10 of Set #9 | Itagi
# Processing request #11 of Set #9 | Saint-Francois
# Processing request #12 of Set #9 | Cochrane
# Processing request #13 of Set #9 | Chimoio
# Processing request #14 of Set #9 | Crossville
# Processing request #15 of Set #9 | Sampit
# Processing request #16 of Set #9 | Goderich
# Processing request #17 of Set #9 | College
# Processing request #18 of Set #9 | Necochea
# Processing request #19 of Set #9 | Corinto
# Processing request #20 of Set #9 | Westport
# Processing request #21 of Set #9 | Whitehorse
# Processing request #22 of Set #9 | Victor Harbor
# Processing request #23 of Set #9 | Henties Bay
# Processing request #24 of Set #9 | Iqaluit
# Processing request #25 of Set #9 | Lewiston
# Processing request #26 of Set #9 | Iralaya
# Processing request #27 of Set #9 | Launceston
# Processing request #28 of Set #9 | Alpena
# Processing request #29 of Set #9 | Vila Franca Do Campo
# Processing request #30 of Set #9 | Namatanai
# Processing request #31 of Set #9 | Beringovskiy
# Processing request #32 of Set #9 | Pemangkat
# City pemangkat not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=pemangkat
# Processing request #33 of Set #9 | Lulea
# Processing request #34 of Set #9 | Bereda
# Processing request #35 of Set #9 | Ahipara
# Processing request #36 of Set #9 | Beni Suef
# Processing request #37 of Set #9 | Oussouye
# Processing request #38 of Set #9 | Edd
# Processing request #39 of Set #9 | Mogzon
# Processing request #40 of Set #9 | Meyungs
# City meyungs not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=meyungs
# Processing request #41 of Set #9 | Jacksonville
# Processing request #42 of Set #9 | Mackay
# Processing request #43 of Set #9 | Bontang
# Processing request #44 of Set #9 | Biloela
# Processing request #45 of Set #9 | Znamenskoye
# Processing request #46 of Set #9 | Buariki
# City buariki not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=buariki
# Processing request #47 of Set #9 | Mut
# Processing request #48 of Set #9 | Sayyan
# Processing request #49 of Set #9 | Te Anau
# Processing request #50 of Set #9 | Talnakh
# Processing request #2 of Set #10 | Natchez
# Processing request #3 of Set #10 | San Ramon
# Processing request #4 of Set #10 | Fortuna
# Processing request #5 of Set #10 | Geraldton
# Processing request #6 of Set #10 | Narok
# Processing request #7 of Set #10 | Boromo
# Processing request #8 of Set #10 | Barbar
# City barbar not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=barbar
# Processing request #9 of Set #10 | Myitkyina
# Processing request #10 of Set #10 | Zyryanovsk
# Processing request #11 of Set #10 | Altay
# Processing request #12 of Set #10 | Huicheng
# Processing request #13 of Set #10 | Maniitsoq
# Processing request #14 of Set #10 | Kudahuvadhoo
# Processing request #15 of Set #10 | Port-Gentil
# Processing request #16 of Set #10 | Kangavar
# Processing request #17 of Set #10 | Dzhebariki-Khaya
# Processing request #18 of Set #10 | Oyonnax
# Processing request #19 of Set #10 | Marzuq
# Processing request #20 of Set #10 | Varhaug
# Processing request #21 of Set #10 | Esperance
# Processing request #22 of Set #10 | Aanekoski
# Processing request #23 of Set #10 | Makuyuni
# Processing request #24 of Set #10 | Olavarria
# Processing request #25 of Set #10 | Atar
# Processing request #26 of Set #10 | Anar Darreh
# City anar darreh not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=anar+darreh
# Processing request #27 of Set #10 | Cortes
# Processing request #28 of Set #10 | Lasa
# Processing request #29 of Set #10 | Paratinga
# Processing request #30 of Set #10 | Lima
# Processing request #31 of Set #10 | Porecatu
# Processing request #32 of Set #10 | Zaozerne
# Processing request #33 of Set #10 | Rio Gallegos
# Processing request #34 of Set #10 | Stephenville
# Processing request #35 of Set #10 | Wanning
# Processing request #36 of Set #10 | Hualmay
# Processing request #37 of Set #10 | Svetlogorsk
# Processing request #38 of Set #10 | Pacific Grove
# Processing request #39 of Set #10 | San-Pedro
# Processing request #40 of Set #10 | Nowy Sacz
# Processing request #41 of Set #10 | Karatau
# Processing request #42 of Set #10 | Eslov
# Processing request #43 of Set #10 | Jerantut
# Processing request #44 of Set #10 | Nagua
# Processing request #45 of Set #10 | Artyk
# City artyk not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=artyk
# Processing request #46 of Set #10 | Fairbanks
# Processing request #47 of Set #10 | Cabo San Lucas
# Processing request #48 of Set #10 | Crab Hill
# City crab hill not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=crab+hill
# Processing request #49 of Set #10 | Verdalsora
# City verdalsora not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=verdalsora
# Processing request #50 of Set #10 | Boysun
# Processing request #2 of Set #11 | Kerteh
# City kerteh not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=kerteh
# Processing request #3 of Set #11 | Poronaysk
# Processing request #4 of Set #11 | Waw
# City waw not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=waw
# Processing request #5 of Set #11 | Neuquen
# Processing request #6 of Set #11 | Tlahualilo
# City tlahualilo not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=tlahualilo
# Processing request #7 of Set #11 | Tokur
# Processing request #8 of Set #11 | Ust-Kalmanka
# Processing request #9 of Set #11 | Yuli
# Processing request #10 of Set #11 | Deputatskiy
# Processing request #11 of Set #11 | Khor
# Processing request #12 of Set #11 | Ilhabela
# Processing request #13 of Set #11 | Chicama
# Processing request #14 of Set #11 | Ostrovnoy
# Processing request #15 of Set #11 | Chapulhuacan
# Processing request #16 of Set #11 | Lavrentiya
# Processing request #17 of Set #11 | Lodhikheda
# Processing request #18 of Set #11 | Concepcion Del Oro
# Processing request #19 of Set #11 | Mayo
# Processing request #20 of Set #11 | Konevo
# Processing request #21 of Set #11 | Marakkanam
# Processing request #22 of Set #11 | Weyburn
# Processing request #23 of Set #11 | Anadyr
# Processing request #24 of Set #11 | Porto Empedocle
# Processing request #25 of Set #11 | Ludvika
# Processing request #26 of Set #11 | Eldikan
# City eldikan not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=eldikan
# Processing request #27 of Set #11 | Hami
# Processing request #28 of Set #11 | Ergani
# Processing request #29 of Set #11 | Barcelona
# Processing request #30 of Set #11 | Uttaradit
# Processing request #31 of Set #11 | Ternate
# Processing request #32 of Set #11 | Nelson Bay
# Processing request #33 of Set #11 | Aksarka
# Processing request #34 of Set #11 | Smithers
# Processing request #35 of Set #11 | Kendari
# Processing request #36 of Set #11 | Itapora
# Processing request #37 of Set #11 | Nishihara
# Processing request #38 of Set #11 | Ituacu
# Processing request #39 of Set #11 | Brumado
# Processing request #40 of Set #11 | Pahrump
# Processing request #41 of Set #11 | Komsomolskiy
# Processing request #42 of Set #11 | Sagaing
# Processing request #43 of Set #11 | Okandja
# City okandja not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=okandja
# Processing request #44 of Set #11 | Peterhead
# Processing request #45 of Set #11 | Kinablangan
# Processing request #46 of Set #11 | Najran
# Processing request #47 of Set #11 | Pindwara
# Processing request #48 of Set #11 | Mormugao
# City mormugao not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=mormugao
# Processing request #49 of Set #11 | Hibbing
# Processing request #50 of Set #11 | Gamba
# Processing request #2 of Set #12 | Rawannawi
# City rawannawi not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=rawannawi
# Processing request #3 of Set #12 | Nayoro
# Processing request #4 of Set #12 | Roald
# Processing request #5 of Set #12 | Saint Simons
# Processing request #6 of Set #12 | Yenagoa
# Processing request #7 of Set #12 | Korla
# City korla not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=korla
# Processing request #8 of Set #12 | Itoman
# Processing request #9 of Set #12 | Kosh-Agach
# Processing request #10 of Set #12 | Plouzane
# Processing request #11 of Set #12 | Ceyhan
# Processing request #12 of Set #12 | Caravelas
# Processing request #13 of Set #12 | Ginda
# Processing request #14 of Set #12 | Tianpeng
# Processing request #15 of Set #12 | Gayny
# Processing request #16 of Set #12 | Ikom
# Processing request #17 of Set #12 | Amga
# Processing request #18 of Set #12 | Sao Joao Da Barra
# Processing request #19 of Set #12 | Sur
# Processing request #20 of Set #12 | Tiarei
# Processing request #21 of Set #12 | Tessalit
# Processing request #22 of Set #12 | Eregli
# Processing request #23 of Set #12 | Mount Pleasant
# Processing request #24 of Set #12 | Sabzevar
# Processing request #25 of Set #12 | Padang
# Processing request #26 of Set #12 | Severo-Kurilsk
# Processing request #27 of Set #12 | Temple
# Processing request #28 of Set #12 | Manzhouli
# Processing request #29 of Set #12 | Bodden Town
# Processing request #30 of Set #12 | Batangafo
# Processing request #31 of Set #12 | Mus
# Processing request #32 of Set #12 | Mount Isa
# Processing request #33 of Set #12 | Saint Anthony
# Processing request #34 of Set #12 | Queimadas
# Processing request #35 of Set #12 | Bilibino
# Processing request #36 of Set #12 | Yar-Sale
# Processing request #37 of Set #12 | Carlisle
# Processing request #38 of Set #12 | Comodoro Rivadavia
# Processing request #39 of Set #12 | Tsienyane
# City tsienyane not found. Skipping... http://api.openweathermap.org/data/2.5/weather?&appid=84263b682936b3cec3c1881184dd334e&q=tsienyane
# Processing request #40 of Set #12 | Hovd
# Processing request #41 of Set #12 | Nouakchott
# Processing request #42 of Set #12 | Igrim
# Processing request #43 of Set #12 | El Alto
# Processing request #44 of Set #12 | Ajdovscina
# Processing request #45 of Set #12 | Kenai
# Processing request #46 of Set #12 | Tabou
# Processing request #47 of Set #12 | Wonthaggi
# Processing request #48 of Set #12 | San Fernando
# Processing request #49 of Set #12 | Teya
# Processing request #50 of Set #12 | Panalingaan
# Processing request #2 of Set #13 | Waingapu
# Processing request #3 of Set #13 | Quarai
# Processing request #4 of Set #13 | Kangaatsiaq
# Processing request #5 of Set #13 | Pochutla
# Processing request #6 of Set #13 | Priladozhskiy
# Processing request #7 of Set #13 | Knysna
# Processing request #8 of Set #13 | Araguaina
# Processing request #9 of Set #13 | Nanyamba
# Processing request #10 of Set #13 | Seymchan
# Processing request #11 of Set #13 | Cidreira
# Processing request #12 of Set #13 | Largs
# Processing request #13 of Set #13 | Suhbaatar
# Processing request #14 of Set #13 | Kraluv Dvur
# Processing request #15 of Set #13 | Maningrida
# -----------------------------
# 607 Records Pulled
# -----------------------------
# -----------------------------
# Retrival Finished, Yo!
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create list for pulled data
weather_data = {
    "City" : city_list,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Lat" : lat,
    "Lng" : lng,
    "Max Temp" : temp,
    "Wind Speed" : wind_speed
}

# Convert above list to a DataFrame
weather_df = pd.DataFrame(weather_data)

# Export DataFrame to csv file
weather_df.to_csv(weather_data_csv)

weather_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0      Cape Town          75      ZA  1567574692        93  14.99  59.00
# 1         Castro           0      CL  1567574879        80   5.82  35.60
# 2          Tigre           0      AR  1567574879        52   4.70  44.60
# 3        Caledon          90      CA  1567574866        78  14.99  73.40
# 4  Leningradskiy          87      RU  1567574788        86   9.04  37.02
#
#    Max Temp  Wind Speed
# 0    -33.93       18.42
# 1    -42.48      -73.76
# 2    -34.42      -58.58
# 3     43.88      -79.86
# 4     69.38      178.42

# %%
weather_df.count()
# Out:
# City          541
# Cloudiness    541
# Country       541
# Date          541
# Humidity      541
# Lat           541
# Lng           541
# Max Temp      541
# Wind Speed    541
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
